# %% [markdown]
# <a href="https://colab.research.google.com/github/AkhandOO7/Sentiment_Analysis/blob/master/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# !pip install twython
# Out:
# ...
#   Created wheel for twython: filename=twython-3.7.0-cp36-none-any.whl size=31995 sha256=74c79250f13135e42dbe6597f8925d8c3be2fb98edb5cb3b7e520e966914851d
#   Stored in directory: /root/.cache/pip/wheels/c2/b0/a3/5c4b4b87b8c9e4d99f1494a0b471f0134a74e5fb33d426d009
# Successfully built twython
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = 'hBc5ajCxjIYxqmXczyI4tmVA8'
consumer_secret = 'EMzrjkxj5ellrtaerfEsKuO2GhrQr3hmOs0QNsehDk0KZXchdL'
access_token = '1013674519377137664-kRWWQI9CtmWOLLrpA8FBYj5KCXzzRa'
access_token_secret = '3dVjyW5urVR3e1wgzgWCoXo7iXJgRjirYj7glvBvWOgEY'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Narendramodi', count=20000)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(100))


print(tweets[0].created_at)
# Out:
#                                                Tweets
# 0   RT @Babulalnapit2: @rsprasad @GoogleIndia @GoI...
# 1   RT @PVishnukant: कुणी कल्पना करणार नाही एवढ्या...
# 2   RT @RichaSingh_Alld: मोदी जी के न्यू इंडिया मे...
# 3   RT @Abhishe09732425: #69000_योग्य_शिक्षक_लाचार...
# 4   RT @ToTheePoint: @KTHopkins Absolutely not sur...
# 5   RT @jaljeevan_: "The biggest challenge we face...
# 6   @POOJADHAKA6 @myogiadityanath @narendramodi @n...
# 7   RT @drharshvardhan: कल तक हम कहते थे, कश्मीर ह...
# 8   RT @fuzzyyadav: #मध्य_प्रदेश शिक्षा व्यवस्था\n...
# 9   @timesofindia @narendramodi PM knows very well...
# 10  RT @BJP4India: अब भारत दुनिया के उन कुछ देशों ...
# 11  @chokidarsandhya @VickyAarya007 @narendramodi ...
# 12        @ASR_21_A @narendramodi @AmitShah Right ASR
# 13  RT @Voice_For_India: I may not be Indian or a ...
# 14  RT @AjitKDoval_NSA: Dear @narendramodi Ji\n\nK...
# 15  RT @Voice_For_India: I may not be Indian or a ...
# ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets                                           polarity
# 0   RT @Emmy_Zje: Trans women are natural women.\n...  {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'comp...
# 1   RT @Emmy_Zje: Trans women are natural women.\n...  {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'comp...
# 2   @ZubyMusic Yep, 'cause feminism wanted it that...  {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'comp...
# 3   RT @Emmy_Zje: Trans women are natural women.\n...  {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'comp...
# 4   RT @sei_riots: Do we still need feminism in Eu...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5   @casxvii They’re disgusting idiots. Some of th...  {'neg': 0.137, 'neu': 0.763, 'pos': 0.1, 'comp...
# 6   RT @Emmy_Zje: Trans women are natural women.\n...  {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'comp...
# 7   RT @Emmy_Zje: Trans women are natural women.\n...  {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'comp...
# ...

# %%
data.shape
# Out:
# (100, 2)

# %%
data.head()
# Out:
#                                               Tweets  ... compound
# 0  RT @Lalit94573963: Todays SUDARSHAN KRIYA was ...  ...   0.7269
# 1  RT @Neha09227409: @Thesiddharthkar \n@Theashwa...  ...   0.5879
# 2  RT @Lalit94573963: Todays SUDARSHAN KRIYA was ...  ...   0.7269
# 3  RT @Neha09227409: @Thesiddharthkar \n@Theashwa...  ...   0.5879
# 4  RT @Umangsh92725745: Aaj  sudarshan kriya Kark...  ...   0.6815
#
# [5 rows x 6 columns]

# %%
# for i in data.polarity[0].keys():
#   data[i] = data.polarity.apply(lambda x:x[i])

# %%
data.drop("compound", 1, inplace=True)

# %%
data.head()
# Out:
#                                               Tweets  ...    pos
# 0  RT @Lalit94573963: Todays SUDARSHAN KRIYA was ...  ...  0.225
# 1  RT @Neha09227409: @Thesiddharthkar \n@Theashwa...  ...  0.231
# 2  RT @Lalit94573963: Todays SUDARSHAN KRIYA was ...  ...  0.225
# 3  RT @Neha09227409: @Thesiddharthkar \n@Theashwa...  ...  0.231
# 4  RT @Umangsh92725745: Aaj  sudarshan kriya Kark...  ...  0.219
#
# [5 rows x 5 columns]

# %%
data.plot(kind="hist")
